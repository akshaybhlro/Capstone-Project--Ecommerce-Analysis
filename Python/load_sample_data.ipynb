# %%
# ================================================================
# Python Script to Load Sample Data to MySQL
# ================================================================

# Data path: D:\Data Analyst\Final Projects\MySQL+Python+PowerBI\1\Raw Data

import pandas as pd
import mysql.connector
from mysql.connector import Error
import os

def connect_to_mysql():
    """Connect to your MySQL database"""
    try:
        connection = mysql.connector.connect(
            host='localhost',
            user='root',        # Change this to your MySQL username
            password='root',    # Change this to your MySQL password
            database='ecommerce_project'
        )
        print("✅ Connected to MySQL successfully!")
        return connection
    except Error as e:
        print(f"❌ Error connecting to MySQL: {e}")
        return None


def load_sample_data():
    """Load sample data from CSV files to MySQL tables"""
    
    print("🚀 Starting Sample Data Load...")
    print("=" * 50)
    
    # Your data path
    data_path = r"D:\Data Analyst\Final Projects\MySQL+Python+PowerBI\1\Raw Data"
    print(f"📁 Looking for CSV files in: {data_path}")
    
    # Connect to database
    connection = connect_to_mysql()
    if not connection:
        return
    
    cursor = connection.cursor()
    
    # File mapping: CSV filename -> MySQL table name
    file_table_mapping = {
        'df_Customers.csv': 'customers',
        'df_Products.csv': 'products', 
        'df_Orders.csv': 'orders',
        'df_OrderItems.csv': 'order_items',
        'df_Payments.csv': 'payments'
    }
    
    for csv_file, table_name in file_table_mapping.items():
        try:
            print(f"\n📁 Loading {csv_file}...")
            
            # Full path to CSV file
            full_path = f"{data_path}\\{csv_file}"
            
            # Read CSV file 
            df = pd.read_csv(full_path)
            print(f"   📊 Loaded {len(df):,} rows from CSV")
            
            # Clean column names
            df.columns = df.columns.str.strip().str.lower()

            # 🧹 Clean any ' UTC' text from datetime columns
            df = df.replace(' UTC', '', regex=True)
            
            # 🧹 Replace blanks/NaN with None → NULL in MySQL
            df = df.where(pd.notnull(df), None)
            df = df.replace(r'^\s*$', None, regex=True)
            
            # 🧹 Remove duplicate rows based on the first column (usually the PK)
            pk_col = df.columns[0]   # assumes 1st column is primary key
            before = len(df)
            df = df.drop_duplicates(subset=[pk_col], keep='first')
            removed = before - len(df)
            if removed > 0:
                print(f"   ⚠️ Removed {removed:,} duplicate records based on '{pk_col}'")
            
            # Clear existing data in table
            cursor.execute(f"DELETE FROM {table_name}")
            
            # Insert data row by row
            rows_inserted = 0
            for index, row in df.iterrows():
                try:
                    placeholders = ', '.join(['%s'] * len(row))
                    columns = ', '.join(df.columns)
                    sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
                    cursor.execute(sql, tuple(row))
                    rows_inserted += 1

                    if rows_inserted % 1000 == 0:
                        print(f"   ⏳ Inserted {rows_inserted:,} rows...")

                except Error as e:
                    print(f"   ⚠️ Row {index} failed in {table_name}: {e}")
                    continue
            
            # Commit the changes
            connection.commit()
            print(f"   ✅ Successfully inserted {rows_inserted:,} rows into {table_name}")
            
        except Exception as e:
            print(f"   ❌ Error loading {csv_file}: {e}")
            continue
    
    # Show final summary
    print(f"\n🎉 Sample Data Loading Complete!")
    print("=" * 50)
    
    tables = ['customers', 'products', 'orders', 'order_items', 'payments']
    for table in tables:
        try:
            cursor.execute(f"SELECT COUNT(*) FROM {table}")
            count = cursor.fetchone()[0]
            print(f"📊 {table}: {count:,} records")
        except:
            print(f"❌ {table}: Error getting count")
    
    cursor.close()
    connection.close()
    print("\n✅ All done! Ready for analysis!")


def test_database_connection():
    """Quick test to make sure everything works"""
    print("🔍 Testing Database Connection...")
    
    connection = connect_to_mysql()
    if connection:
        cursor = connection.cursor()
        cursor.execute("SELECT COUNT(*) FROM customers LIMIT 5")
        result = cursor.fetchone()
        print(f"✅ Test successful! Found {result[0]} customers")
        cursor.close()
        connection.close()
        return True
    return False


if __name__ == "__main__":
    print("🎯 E-commerce Sample Data Loader")
    print()
    
    if test_database_connection():
        print("✅ Database connection works!")
        input("\nPress Enter to start loading sample data...")
        load_sample_data()
    else:
        print("❌ Please check your MySQL connection settings")
        print("Update the username and password in the connect_to_mysql() function")
# Out:
# 🎯 E-commerce Sample Data Loader
#
# 🔍 Testing Database Connection...
# ✅ Connected to MySQL successfully!
# ✅ Test successful! Found 0 customers
# ✅ Database connection works!
# Press Enter to start loading sample data...
# 🚀 Starting Sample Data Load...
# ==================================================
# 📁 Looking for CSV files in: D:\Data Analyst\Final Projects\MySQL+Python+PowerBI\1\Raw Data
# ✅ Connected to MySQL successfully!
#
# 📁 Loading df_Customers.csv...
#    📊 Loaded 89,316 rows from CSV
#    ⏳ Inserted 1,000 rows...
#    ⏳ Inserted 2,000 rows...
#    ⏳ Inserted 3,000 rows...
#    ⏳ Inserted 4,000 rows...
#    ⏳ Inserted 5,000 rows...
#    ⏳ Inserted 6,000 rows...
#    ⏳ Inserted 7,000 rows...
#    ⏳ Inserted 8,000 rows...
#    ⏳ Inserted 9,000 rows...
#    ⏳ Inserted 10,000 rows...
#    ⏳ Inserted 11,000 rows...
#    ⏳ Inserted 12,000 rows...
#    ⏳ Inserted 13,000 rows...
#    ⏳ Inserted 14,000 rows...
#    ⏳ Inserted 15,000 rows...
#    ⏳ Inserted 16,000 rows...
#    ⏳ Inserted 17,000 rows...
#    ⏳ Inserted 18,000 rows...
#    ⏳ Inserted 19,000 rows...
#    ⏳ Inserted 20,000 rows...
#    ⏳ Inserted 21,000 rows...
#    ⏳ Inserted 22,000 rows...
#    ⏳ Inserted 23,000 rows...
#    ⏳ Inserted 24,000 rows...
#    ⏳ Inserted 25,000 rows...
#    ⏳ Inserted 26,000 rows...
#    ⏳ Inserted 27,000 rows...
#    ⏳ Inserted 28,000 rows...
#    ⏳ Inserted 29,000 rows...
#    ⏳ Inserted 30,000 rows...
#    ⏳ Inserted 31,000 rows...
#    ⏳ Inserted 32,000 rows...
#    ⏳ Inserted 33,000 rows...
#    ⏳ Inserted 34,000 rows...
#    ⏳ Inserted 35,000 rows...
#    ⏳ Inserted 36,000 rows...
#    ⏳ Inserted 37,000 rows...
#    ⏳ Inserted 38,000 rows...
#    ⏳ Inserted 39,000 rows...
#    ⏳ Inserted 40,000 rows...
#    ⏳ Inserted 41,000 rows...
#    ⏳ Inserted 42,000 rows...
#    ⏳ Inserted 43,000 rows...
#    ⏳ Inserted 44,000 rows...
#    ⏳ Inserted 45,000 rows...
#    ⏳ Inserted 46,000 rows...
#    ⏳ Inserted 47,000 rows...
#    ⏳ Inserted 48,000 rows...
#    ⏳ Inserted 49,000 rows...
#    ⏳ Inserted 50,000 rows...
#    ⏳ Inserted 51,000 rows...
#    ⏳ Inserted 52,000 rows...
#    ⏳ Inserted 53,000 rows...
#    ⏳ Inserted 54,000 rows...
#    ⏳ Inserted 55,000 rows...
#    ⏳ Inserted 56,000 rows...
#    ⏳ Inserted 57,000 rows...
#    ⏳ Inserted 58,000 rows...
#    ⏳ Inserted 59,000 rows...
#    ⏳ Inserted 60,000 rows...
#    ⏳ Inserted 61,000 rows...
#    ⏳ Inserted 62,000 rows...
#    ⏳ Inserted 63,000 rows...
#    ⏳ Inserted 64,000 rows...
#    ⏳ Inserted 65,000 rows...
#    ⏳ Inserted 66,000 rows...
#    ⏳ Inserted 67,000 rows...
#    ⏳ Inserted 68,000 rows...
#    ⏳ Inserted 69,000 rows...
#    ⏳ Inserted 70,000 rows...
#    ⏳ Inserted 71,000 rows...
#    ⏳ Inserted 72,000 rows...
#    ⏳ Inserted 73,000 rows...
#    ⏳ Inserted 74,000 rows...
#    ⏳ Inserted 75,000 rows...
#    ⏳ Inserted 76,000 rows...
#    ⏳ Inserted 77,000 rows...
#    ⏳ Inserted 78,000 rows...
#    ⏳ Inserted 79,000 rows...
#    ⏳ Inserted 80,000 rows...
#    ⏳ Inserted 81,000 rows...
#    ⏳ Inserted 82,000 rows...
#    ⏳ Inserted 83,000 rows...
#    ⏳ Inserted 84,000 rows...
#    ⏳ Inserted 85,000 rows...
#    ⏳ Inserted 86,000 rows...
#    ⏳ Inserted 87,000 rows...
#    ⏳ Inserted 88,000 rows...
#    ⏳ Inserted 89,000 rows...
#    ✅ Successfully inserted 89,316 rows into customers
#
# 📁 Loading df_Products.csv...
#    📊 Loaded 89,316 rows from CSV
#    ⚠️ Removed 61,865 duplicate records based on 'product_id'
#    ⏳ Inserted 1,000 rows...
#    ⚠️ Row 2150 failed in products: 1054 (42S22): Unknown column 'nan' in 'field list'
#    ⏳ Inserted 2,000 rows...
#    ⏳ Inserted 3,000 rows...
#    ⏳ Inserted 4,000 rows...
#    ⏳ Inserted 5,000 rows...
#    ⏳ Inserted 6,000 rows...
#    ⏳ Inserted 7,000 rows...
#    ⏳ Inserted 8,000 rows...
#    ⚠️ Row 13628 failed in products: 1054 (42S22): Unknown column 'nan' in 'field list'
#    ⏳ Inserted 9,000 rows...
#    ⏳ Inserted 10,000 rows...
#    ⏳ Inserted 11,000 rows...
#    ⏳ Inserted 12,000 rows...
#    ⏳ Inserted 13,000 rows...
#    ⏳ Inserted 14,000 rows...
#    ⏳ Inserted 15,000 rows...
#    ⏳ Inserted 16,000 rows...
#    ⏳ Inserted 17,000 rows...
#    ⏳ Inserted 18,000 rows...
#    ⏳ Inserted 19,000 rows...
#    ⏳ Inserted 20,000 rows...
#    ⏳ Inserted 21,000 rows...
#    ⏳ Inserted 22,000 rows...
#    ⏳ Inserted 23,000 rows...
#    ⏳ Inserted 24,000 rows...
#    ⏳ Inserted 25,000 rows...
#    ⏳ Inserted 26,000 rows...
#    ⏳ Inserted 27,000 rows...
#    ✅ Successfully inserted 27,449 rows into products
#
# 📁 Loading df_Orders.csv...
#    📊 Loaded 89,316 rows from CSV
#    ⏳ Inserted 1,000 rows...
#    ⏳ Inserted 2,000 rows...
#    ⏳ Inserted 3,000 rows...
#    ⏳ Inserted 4,000 rows...
#    ⏳ Inserted 5,000 rows...
#    ⏳ Inserted 6,000 rows...
#    ⏳ Inserted 7,000 rows...
#    ⏳ Inserted 8,000 rows...
#    ⏳ Inserted 9,000 rows...
#    ⏳ Inserted 10,000 rows...
#    ⏳ Inserted 11,000 rows...
#    ⏳ Inserted 12,000 rows...
#    ⏳ Inserted 13,000 rows...
#    ⏳ Inserted 14,000 rows...
#    ⏳ Inserted 15,000 rows...
#    ⏳ Inserted 16,000 rows...
#    ⏳ Inserted 17,000 rows...
#    ⏳ Inserted 18,000 rows...
#    ⏳ Inserted 19,000 rows...
#    ⏳ Inserted 20,000 rows...
#    ⏳ Inserted 21,000 rows...
#    ⏳ Inserted 22,000 rows...
#    ⏳ Inserted 23,000 rows...
#    ⏳ Inserted 24,000 rows...
#    ⏳ Inserted 25,000 rows...
#    ⏳ Inserted 26,000 rows...
#    ⏳ Inserted 27,000 rows...
#    ⏳ Inserted 28,000 rows...
#    ⏳ Inserted 29,000 rows...
#    ⏳ Inserted 30,000 rows...
#    ⏳ Inserted 31,000 rows...
#    ⏳ Inserted 32,000 rows...
#    ⏳ Inserted 33,000 rows...
#    ⏳ Inserted 34,000 rows...
#    ⏳ Inserted 35,000 rows...
#    ⏳ Inserted 36,000 rows...
#    ⏳ Inserted 37,000 rows...
#    ⏳ Inserted 38,000 rows...
#    ⏳ Inserted 39,000 rows...
#    ⏳ Inserted 40,000 rows...
#    ⏳ Inserted 41,000 rows...
#    ⏳ Inserted 42,000 rows...
#    ⏳ Inserted 43,000 rows...
#    ⏳ Inserted 44,000 rows...
#    ⏳ Inserted 45,000 rows...
#    ⏳ Inserted 46,000 rows...
#    ⏳ Inserted 47,000 rows...
#    ⏳ Inserted 48,000 rows...
#    ⏳ Inserted 49,000 rows...
#    ⏳ Inserted 50,000 rows...
#    ⏳ Inserted 51,000 rows...
#    ⏳ Inserted 52,000 rows...
#    ⏳ Inserted 53,000 rows...
#    ⏳ Inserted 54,000 rows...
#    ⏳ Inserted 55,000 rows...
#    ⏳ Inserted 56,000 rows...
#    ⏳ Inserted 57,000 rows...
#    ⏳ Inserted 58,000 rows...
#    ⏳ Inserted 59,000 rows...
#    ⏳ Inserted 60,000 rows...
#    ⏳ Inserted 61,000 rows...
#    ⏳ Inserted 62,000 rows...
#    ⏳ Inserted 63,000 rows...
#    ⏳ Inserted 64,000 rows...
#    ⏳ Inserted 65,000 rows...
#    ⏳ Inserted 66,000 rows...
#    ⏳ Inserted 67,000 rows...
#    ⏳ Inserted 68,000 rows...
#    ⏳ Inserted 69,000 rows...
#    ⏳ Inserted 70,000 rows...
#    ⏳ Inserted 71,000 rows...
#    ⏳ Inserted 72,000 rows...
#    ⏳ Inserted 73,000 rows...
#    ⏳ Inserted 74,000 rows...
#    ⏳ Inserted 75,000 rows...
#    ⏳ Inserted 76,000 rows...
#    ⏳ Inserted 77,000 rows...
#    ⏳ Inserted 78,000 rows...
#    ⏳ Inserted 79,000 rows...
#    ⏳ Inserted 80,000 rows...
#    ⏳ Inserted 81,000 rows...
#    ⏳ Inserted 82,000 rows...
#    ⏳ Inserted 83,000 rows...
#    ⏳ Inserted 84,000 rows...
#    ⏳ Inserted 85,000 rows...
#    ⏳ Inserted 86,000 rows...
#    ⏳ Inserted 87,000 rows...
#    ⏳ Inserted 88,000 rows...
#    ⏳ Inserted 89,000 rows...
#    ✅ Successfully inserted 89,316 rows into orders
#
# 📁 Loading df_OrderItems.csv...
#    📊 Loaded 89,316 rows from CSV
#    ⏳ Inserted 1,000 rows...
#    ⏳ Inserted 2,000 rows...
#    ⚠️ Row 2150 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 3,000 rows...
#    ⏳ Inserted 4,000 rows...
#    ⏳ Inserted 5,000 rows...
#    ⏳ Inserted 6,000 rows...
#    ⏳ Inserted 7,000 rows...
#    ⚠️ Row 7473 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 8,000 rows...
#    ⏳ Inserted 9,000 rows...
#    ⏳ Inserted 10,000 rows...
#    ⏳ Inserted 11,000 rows...
#    ⏳ Inserted 12,000 rows...
#    ⏳ Inserted 13,000 rows...
#    ⚠️ Row 13628 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 14,000 rows...
#    ⏳ Inserted 15,000 rows...
#    ⏳ Inserted 16,000 rows...
#    ⏳ Inserted 17,000 rows...
#    ⏳ Inserted 18,000 rows...
#    ⏳ Inserted 19,000 rows...
#    ⏳ Inserted 20,000 rows...
#    ⏳ Inserted 21,000 rows...
#    ⏳ Inserted 22,000 rows...
#    ⏳ Inserted 23,000 rows...
#    ⏳ Inserted 24,000 rows...
#    ⏳ Inserted 25,000 rows...
#    ⏳ Inserted 26,000 rows...
#    ⏳ Inserted 27,000 rows...
#    ⏳ Inserted 28,000 rows...
#    ⚠️ Row 28114 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 29,000 rows...
#    ⏳ Inserted 30,000 rows...
#    ⏳ Inserted 31,000 rows...
#    ⏳ Inserted 32,000 rows...
#    ⚠️ Row 32791 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 33,000 rows...
#    ⏳ Inserted 34,000 rows...
#    ⏳ Inserted 35,000 rows...
#    ⏳ Inserted 36,000 rows...
#    ⏳ Inserted 37,000 rows...
#    ⏳ Inserted 38,000 rows...
#    ⚠️ Row 38130 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 39,000 rows...
#    ⚠️ Row 39021 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 40,000 rows...
#    ⏳ Inserted 41,000 rows...
#    ⏳ Inserted 42,000 rows...
#    ⏳ Inserted 43,000 rows...
#    ⏳ Inserted 44,000 rows...
#    ⏳ Inserted 45,000 rows...
#    ⏳ Inserted 46,000 rows...
#    ⏳ Inserted 47,000 rows...
#    ⏳ Inserted 48,000 rows...
#    ⏳ Inserted 49,000 rows...
#    ⚠️ Row 49124 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 50,000 rows...
#    ⏳ Inserted 51,000 rows...
#    ⏳ Inserted 52,000 rows...
#    ⏳ Inserted 53,000 rows...
#    ⏳ Inserted 54,000 rows...
#    ⏳ Inserted 55,000 rows...
#    ⚠️ Row 55696 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 56,000 rows...
#    ⚠️ Row 56195 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 57,000 rows...
#    ⚠️ Row 57156 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 58,000 rows...
#    ⏳ Inserted 59,000 rows...
#    ⏳ Inserted 60,000 rows...
#    ⏳ Inserted 61,000 rows...
#    ⏳ Inserted 62,000 rows...
#    ⏳ Inserted 63,000 rows...
#    ⚠️ Row 63531 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 64,000 rows...
#    ⏳ Inserted 65,000 rows...
#    ⏳ Inserted 66,000 rows...
#    ⏳ Inserted 67,000 rows...
#    ⏳ Inserted 68,000 rows...
#    ⚠️ Row 68946 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 69,000 rows...
#    ⏳ Inserted 70,000 rows...
#    ⚠️ Row 70321 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 71,000 rows...
#    ⏳ Inserted 72,000 rows...
#    ⏳ Inserted 73,000 rows...
#    ⏳ Inserted 74,000 rows...
#    ⏳ Inserted 75,000 rows...
#    ⏳ Inserted 76,000 rows...
#    ⏳ Inserted 77,000 rows...
#    ⏳ Inserted 78,000 rows...
#    ⏳ Inserted 79,000 rows...
#    ⏳ Inserted 80,000 rows...
#    ⏳ Inserted 81,000 rows...
#    ⏳ Inserted 82,000 rows...
#    ⏳ Inserted 83,000 rows...
#    ⏳ Inserted 84,000 rows...
#    ⏳ Inserted 85,000 rows...
#    ⏳ Inserted 86,000 rows...
#    ⏳ Inserted 87,000 rows...
#    ⏳ Inserted 88,000 rows...
#    ⚠️ Row 88303 failed in order_items: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`ecommerce_project`.`order_items`, CONSTRAINT `order_items_ibfk_2` FOREIGN KEY (`product_id`) REFERENCES `products` (`product_id`))
#    ⏳ Inserted 89,000 rows...
#    ✅ Successfully inserted 89,301 rows into order_items
#
# 📁 Loading df_Payments.csv...
#    📊 Loaded 89,316 rows from CSV
#    ⏳ Inserted 1,000 rows...
#    ⏳ Inserted 2,000 rows...
#    ⏳ Inserted 3,000 rows...
#    ⏳ Inserted 4,000 rows...
#    ⏳ Inserted 5,000 rows...
#    ⏳ Inserted 6,000 rows...
#    ⏳ Inserted 7,000 rows...
#    ⏳ Inserted 8,000 rows...
#    ⏳ Inserted 9,000 rows...
#    ⏳ Inserted 10,000 rows...
#    ⏳ Inserted 11,000 rows...
#    ⏳ Inserted 12,000 rows...
#    ⏳ Inserted 13,000 rows...
#    ⏳ Inserted 14,000 rows...
#    ⏳ Inserted 15,000 rows...
#    ⏳ Inserted 16,000 rows...
#    ⏳ Inserted 17,000 rows...
#    ⏳ Inserted 18,000 rows...
#    ⏳ Inserted 19,000 rows...
#    ⏳ Inserted 20,000 rows...
#    ⏳ Inserted 21,000 rows...
#    ⏳ Inserted 22,000 rows...
#    ⏳ Inserted 23,000 rows...
#    ⏳ Inserted 24,000 rows...
#    ⏳ Inserted 25,000 rows...
#    ⏳ Inserted 26,000 rows...
#    ⏳ Inserted 27,000 rows...
#    ⏳ Inserted 28,000 rows...
#    ⏳ Inserted 29,000 rows...
#    ⏳ Inserted 30,000 rows...
#    ⏳ Inserted 31,000 rows...
#    ⏳ Inserted 32,000 rows...
#    ⏳ Inserted 33,000 rows...
#    ⏳ Inserted 34,000 rows...
#    ⏳ Inserted 35,000 rows...
#    ⏳ Inserted 36,000 rows...
#    ⏳ Inserted 37,000 rows...
#    ⏳ Inserted 38,000 rows...
#    ⏳ Inserted 39,000 rows...
#    ⏳ Inserted 40,000 rows...
#    ⏳ Inserted 41,000 rows...
#    ⏳ Inserted 42,000 rows...
#    ⏳ Inserted 43,000 rows...
#    ⏳ Inserted 44,000 rows...
#    ⏳ Inserted 45,000 rows...
#    ⏳ Inserted 46,000 rows...
#    ⏳ Inserted 47,000 rows...
#    ⏳ Inserted 48,000 rows...
#    ⏳ Inserted 49,000 rows...
#    ⏳ Inserted 50,000 rows...
#    ⏳ Inserted 51,000 rows...
#    ⏳ Inserted 52,000 rows...
#    ⏳ Inserted 53,000 rows...
#    ⏳ Inserted 54,000 rows...
#    ⏳ Inserted 55,000 rows...
#    ⏳ Inserted 56,000 rows...
#    ⏳ Inserted 57,000 rows...
#    ⏳ Inserted 58,000 rows...
#    ⏳ Inserted 59,000 rows...
#    ⏳ Inserted 60,000 rows...
#    ⏳ Inserted 61,000 rows...
#    ⏳ Inserted 62,000 rows...
#    ⏳ Inserted 63,000 rows...
#    ⏳ Inserted 64,000 rows...
#    ⏳ Inserted 65,000 rows...
#    ⏳ Inserted 66,000 rows...
#    ⏳ Inserted 67,000 rows...
#    ⏳ Inserted 68,000 rows...
#    ⏳ Inserted 69,000 rows...
#    ⏳ Inserted 70,000 rows...
#    ⏳ Inserted 71,000 rows...
#    ⏳ Inserted 72,000 rows...
#    ⏳ Inserted 73,000 rows...
#    ⏳ Inserted 74,000 rows...
#    ⏳ Inserted 75,000 rows...
#    ⏳ Inserted 76,000 rows...
#    ⏳ Inserted 77,000 rows...
#    ⏳ Inserted 78,000 rows...
#    ⏳ Inserted 79,000 rows...
#    ⏳ Inserted 80,000 rows...
#    ⏳ Inserted 81,000 rows...
#    ⏳ Inserted 82,000 rows...
#    ⏳ Inserted 83,000 rows...
#    ⏳ Inserted 84,000 rows...
#    ⏳ Inserted 85,000 rows...
#    ⏳ Inserted 86,000 rows...
#    ⏳ Inserted 87,000 rows...
#    ⏳ Inserted 88,000 rows...
#    ⏳ Inserted 89,000 rows...
#    ✅ Successfully inserted 89,316 rows into payments
#
# 🎉 Sample Data Loading Complete!
# ==================================================
# 📊 customers: 89,316 records
# 📊 products: 27,449 records
# 📊 orders: 89,316 records
# 📊 order_items: 89,301 records
# 📊 payments: 89,316 records
#
# ✅ All done! Ready for analysis!
